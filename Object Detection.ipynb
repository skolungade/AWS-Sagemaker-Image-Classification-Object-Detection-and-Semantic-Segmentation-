# %% [markdown]
# # Download the Data

# %%
# !pip3 install tqdm
# !pip3 install pillow --upgrade
# Out:
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages (4.44.1)
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/amazonei_tensorflow_p36/bin/python -m pip install --upgrade pip' command.
# Collecting pillow
#   Downloading Pillow-7.2.0-cp36-cp36m-manylinux1_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 9.7 MB/s eta 0:00:01
# Installing collected packages: pillow
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.0.0
#     Uninstalling Pillow-7.0.0:
#       Successfully uninstalled Pillow-7.0.0
# Successfully installed pillow-7.2.0
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/amazonei_tensorflow_p36/bin/python -m pip install --upgrade pip' command.

# %%
# %matplotlib inline

import os
import tarfile
import urllib
import shutil
import json
import random
import numpy as np
import boto3
import sagemaker

from tqdm import tqdm
from sagemaker.amazon.amazon_estimator import get_image_uri
from matplotlib import pyplot as plt
from xml.etree import ElementTree as ET
from PIL import Image, ImageDraw, ImageFont

urls = ['http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz',
        'http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz']

def download_and_extract(data_dir, download_dir):
    for url in urls:
        target_file = url.split('/')[-1]
        if target_file not in os.listdir(download_dir):
            print('Downloading', url)
            urllib.request.urlretrieve(url, os.path.join(download_dir, target_file))
            tf = tarfile.open(url.split('/')[-1])
            tf.extractall(data_dir)
        else:
            print('Already downloaded', url)

if not os.path.isdir('data'):
    os.mkdir('data')

download_and_extract('data', '.')
# Out:
# Downloading http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Downloading http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz

# %% [markdown]
# # Extracting Annotations from XML Format

# %%
xml_dir = 'data/annotations/xmls/'
xml_files = [os.path.join(xml_dir, x) for x in os.listdir(xml_dir) if x[-3:] == 'xml']
xml_files[0]
# Out:
# 'data/annotations/xmls/samoyed_156.xml'

# %%
classes = ['cat', 'dog']
categories = [
    {
        'class_id': 0,
        'name': 'cat'
    },
    {
        'class_id': 1,
        'name': 'dog'
    }
]

# %%
def extract_annotation(xml_file_path):
    
    tree = ET.parse(xml_file_path)
    root = tree.getroot()
    annotation = {}
    
    annotation['file'] = root.find('filename').text
    annotation['categories'] = categories
    
    size = root.find('size')
    
    annotation['image_size'] = [{
        'width': int(size.find('width').text),
        'height': int(size.find('height').text),
        'depth': int(size.find('depth').text)
    }]
    
    annotation['annotations'] = []
    
    for item in root.iter('object'):
        class_id = classes.index(item.find('name').text)
        ymin, xmin, ymax, xmax = None, None, None, None
        
        for box in item.findall('bndbox'):
            xmin = int(box.find("xmin").text)
            ymin = int(box.find("ymin").text)
            xmax = int(box.find("xmax").text)
            ymax = int(box.find("ymax").text)
        
            if all([xmin, ymin, xmax, ymax]) is not None:
                 annotation['annotations'].append({
                     'class_id': class_id,
                     'left': xmin,
                     'top': ymin,
                     'width': xmax - xmin,
                     'height': ymax - ymin
                 })
    return annotation

# %%
extract_annotation(xml_files[0])
# Out:
# {'file': 'samoyed_156.jpg',
#  'categories': [{'class_id': 0, 'name': 'cat'},
#   {'class_id': 1, 'name': 'dog'}],
#  'image_size': [{'width': 500, 'height': 333, 'depth': 3}],
#  'annotations': [{'class_id': 1,
#    'left': 120,
#    'top': 1,
#    'width': 166,
#    'height': 233}]}

# %% [markdown]
# # Visualize Data

# %%
def plot_example(plt, annot, image_file_path, rows, cols, index):
    img = Image.open(image_file_path)
    draw = ImageDraw.Draw(img)
    font = ImageFont.truetype('/usr/share/fonts/dejavu/DejaVuSerif-Bold.ttf', 20)
    
    for a in annot['annotations']:
        box = [
            int(a['left']), int(a['top']),
            int(a['left']) + int(a['width']),
            int(a['top']) + int(a['height'])
        ]
        draw.rectangle(box, outline='yellow', width=4)
        draw.text((box[0], box[1]), classes[int(a['class_id'])], font=font)
    plt.subplot(rows, cols, index + 1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img)
    return plt

def show_random_annotations(plt):
    plt.figure(figsize=(16, 16))
    for i in range(0, 9):
        index = random.randint(0, len(xml_files) - 1)
        
        annot = extract_annotation(xml_files[index])
        image_file_path = os.path.join('data/images/', annot['file'])

        plt = plot_example(plt, annot, image_file_path, 3, 3, i)
    plt.show()

# %%
show_random_annotations(plt)

# %% [markdown]
# # SageMaker Setup

# %%
role = sagemaker.get_execution_role()
bucket_name = 'petsobjectdetection'
training_image = get_image_uri(boto3.Session().region_name, 'object-detection',
                              repo_version='latest')
print(training_image)
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 811284229777.dkr.ecr.us-east-1.amazonaws.com/object-detection:latest

# %%
folders = ['train', 'train_annotation', 'validation', 'validation_annotation']

for folder in folders:
    if os.path.isdir(folder):
        shutil.rmtree(folder)
    os.mkdir(folder)

# %% [markdown]
# # Preparing Data for SageMaker

# %%
print('Total examples:', len(xml_files))
# Out:
# Total examples: 3686

# %%
for xml_file in tqdm(xml_files):
    target_set = 'train' if random.randint(0, 99) < 75 else 'validation'
    annot = extract_annotation(xml_file)
    image_file_path = os.path.join('data/images/', annot['file'])
    image_target_path = os.path.join(target_set, annot['file'])
    shutil.copy(image_file_path, image_target_path)
    json_file_path = os.path.join(target_set + '_annotation', annot['file'][:-3] + 'json')
    with open(json_file_path, 'w') as f:
        json.dump(annot, f)
# Out:
# 100%|██████████| 3686/3686 [00:01<00:00, 1857.51it/s]

# %%
train_images = os.listdir('train')
train_annots = os.listdir('train_annotation')

# %%
print(len(train_annots), len(train_images))
# Out:
# 2771 2771

# %%
for image in train_images:
    key = image.split('.')[0]
    json_file = key + '.json'
    if json_file not in train_annots:
        print('Not found', json_file)

# %% [markdown]
# # Uploading Data to S3

# %%
# %%time
sess = sagemaker.Session()

print('Uploading data..')
s3_train_path = sess.upload_data(path='train', bucket=bucket_name, key_prefix='train')
print('Training images uploaded')
s3_train_annotation_path = sess.upload_data(path='train_annotation', bucket=bucket_name,
                                     key_prefix='train_annotation')
print('Training Annotations uploaded')
s3_validation_path = sess.upload_data(path='validation', bucket=bucket_name,
                                      key_prefix='validation')
print('Validation images uploaded')
s3_validation_annotation_path = sess.upload_data(path='validation_annotation', bucket=bucket_name,
                                          key_prefix='validation_annotation')
print('Validation Annotations uploaded')
# Out:
# Uploading data..
# Training images uploaded
# Training Annotations uploaded
# Validation images uploaded
# Validation Annotations uploaded
# CPU times: user 54.2 s, sys: 3.56 s, total: 57.8 s
# Wall time: 8min 4s

# %%
s3_validation_annotation_path
# Out:
# 's3://petsobjectdetection/validation_annotation'

# %% [markdown]
# # SageMaker Estimator

# %%
model = sagemaker.estimator.Estimator(
    training_image,
    role=role,
    train_instance_count=1,
    train_instance_type='ml.p3.2xlarge',
    train_volume_size=100,
    train_max_run=36000,
    input_mode='File',
    output_path='s3://petsobjectdetection/output',
    sagemaker_session=sess
)
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# # Hyperparameters

# %%
model.set_hyperparameters(
    base_network='resnet-50',
    num_classes=2,
    use_pretrained_model=1,
    mini_batch_size=16,
    epochs=15,
    learning_rate=0.001,
    lr_scheduler_step='10',
    lr_scheduler_factor=0.1,
    optimizer='sgd',
    momentum=0.9,
    weight_decay=0.0005,
    overlap_threshold=0.5,
    nms_threshold=0.45,
    image_shape=512,
    num_training_samples=len(train_annots)
)

# %% [markdown]
# # Data Channels

# %%
train_data = sagemaker.session.s3_input(s3_train_path, distribution='FullyReplicated',
                          content_type='application/x-image', s3_data_type='S3Prefix')
validation_data = sagemaker.session.s3_input(s3_validation_path, distribution='FullyReplicated',
                          content_type='application/x-image', s3_data_type='S3Prefix')

train_annotation_data = sagemaker.session.s3_input(s3_train_annotation_path, distribution='FullyReplicated',
                          content_type='application/x-image', s3_data_type='S3Prefix')
validation_annotation_data = sagemaker.session.s3_input(s3_validation_annotation_path, distribution='FullyReplicated',
                          content_type='application/x-image', s3_data_type='S3Prefix')
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
data_channels = {
    'train': train_data,
    'train_annotation': train_annotation_data,
    'validation': validation_data,
    'validation_annotation': validation_annotation_data
}

# %% [markdown]
# # Model Training

# %%
model.fit(inputs=data_channels, logs=True)
# Out:
# 2020-07-29 03:53:46 Starting - Starting the training job...
# 2020-07-29 03:53:48 Starting - Launching requested ML instances......
# 2020-07-29 03:55:10 Starting - Preparing the instances for training......
# 2020-07-29 03:56:07 Downloading - Downloading input data.........
# 2020-07-29 03:57:44 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# [07/29/2020 03:57:47 INFO 139835754809152] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'label_width': u'350', u'early_stopping_min_epochs': u'10', u'epochs': u'30', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'32', u'use_pretrained_model': u'0', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'', u'early_stopping': u'False', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'', u'base_network': u'vgg-16', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'300'}
# [07/29/2020 03:57:47 INFO 139835754809152] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'learning_rate': u'0.001', u'epochs': u'15', u'nms_threshold': u'0.45', u'optimizer': u'sgd', u'base_network': u'resnet-50', u'image_shape': u'512', u'lr_scheduler_step': u'10', u'momentum': u'0.9', u'overlap_threshold': u'0.5', u'num_training_samples': u'2771', u'mini_batch_size': u'16', u'weight_decay': u'0.0005', u'use_pretrained_model': u'1', u'num_classes': u'2', u'lr_scheduler_factor': u'0.1'}
# [07/29/2020 03:57:47 INFO 139835754809152] Final configuration: {u'label_width': u'350', u'early_stopping_min_epochs': u'10', u'epochs': u'15', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'16', u'use_pretrained_model': u'1', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'10', u'early_stopping': u'False', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'2771', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'2', u'base_network': u'resnet-50', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'512'}
# Process 1 is a worker.
# [07/29/2020 03:57:47 INFO 139835754809152] Using default worker.
# [07/29/2020 03:57:47 INFO 139835754809152] Loaded iterator creator application/x-image for content type ('application/x-image', '1.0')
# [07/29/2020 03:57:47 INFO 139835754809152] Loaded iterator creator application/x-recordio for content type ('application/x-recordio', '1.0')
# [07/29/2020 03:57:47 INFO 139835754809152] Loaded iterator creator image/png for content type ('image/png', '1.0')
# [07/29/2020 03:57:47 INFO 139835754809152] Loaded iterator creator image/jpeg for content type ('image/jpeg', '1.0')
# [07/29/2020 03:57:47 INFO 139835754809152] Checkpoint loading and saving are disabled.
# [07/29/2020 03:57:48 INFO 139835754809152] nvidia-smi took: 0.0754680633545 secs to identify 1 gpus
# Creating .rec file from /opt/ml/input/data/train/train.lst in /opt/ml/input/data/train
# Corrupt JPEG data: premature end of data segment
# time: 0.0532670021057  count: 0
# time: 1.13131189346  count: 1000
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# time: 1.38711905479  count: 2000
# Creating .rec file from /opt/ml/input/data/validation/val.lst in /opt/ml/input/data/validation
# time: 0.0290579795837  count: 0
# [07/29/2020 03:57:54 INFO 139835754809152] Number of GPUs being used: 1
# [07/29/2020 03:57:54 WARNING 139835754809152] Training images are resized to image shape (3, 512, 512)
# [03:57:54] /opt/brazil-pkg-cache/packages/MXNetECL/MXNetECL-v1.4.1.1911.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/train/train.rec, use 7 threads for decoding..
# [03:57:54] /opt/brazil-pkg-cache/packages/MXNetECL/MXNetECL-v1.4.1.1911.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/train/train.rec, label padding width: 350
# [07/29/2020 03:57:57 WARNING 139835754809152] Validation images are resized to image shape (3, 512, 512)
# [03:57:57] /opt/brazil-pkg-cache/packages/MXNetECL/MXNetECL-v1.4.1.1911.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/validation/val.rec, use 7 threads for decoding..
# [03:57:57] /opt/brazil-pkg-cache/packages/MXNetECL/MXNetECL-v1.4.1.1911.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/validation/val.rec, label padding width: 350
# [07/29/2020 03:57:58 INFO 139835754809152] Number of GPUs being used: 1
# [07/29/2020 03:57:58 INFO 139835754809152] Using [gpu(0)] as training context.
# [07/29/2020 03:57:58 INFO 139835754809152] Number of GPUs being used: 1
# [07/29/2020 03:57:58 INFO 139835754809152] Create Store: device
# [07/29/2020 03:57:58 INFO 139835754809152] Using (gpu(0)) as training context.
# [07/29/2020 03:57:58 INFO 139835754809152] Start training from pretrained model 1.
# [03:57:58] /opt/brazil-pkg-cache/packages/MXNetECL/MXNetECL-v1.4.1.1911.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.8.0. Attempting to upgrade...
# [03:57:59] /opt/brazil-pkg-cache/packages/MXNetECL/MXNetECL-v1.4.1.1911.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# [07/29/2020 03:57:59 INFO 139835754809152] Loaded pretrained model parameters.
# [07/29/2020 03:58:13 INFO 139835754809152] Creating a new state instance.
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1595995093.976376, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1595995093.97625}
#
# [03:58:14] /opt/brazil-pkg-cache/packages/MXNetECL/MXNetECL-v1.4.1.1911.0/AL2012/generic-flavor/src/src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [07/29/2020 03:58:51 INFO 139835754809152] Epoch:    0, batches:    100, num_examples:   1600, 42.7 samples/sec, epoch time so far:  0:00:37.508508
# [07/29/2020 03:59:14 WARNING 139835754809152] Expected number of batches: 173, did not match the number of batches processed: 174. This may happen when some images or annotations are invalid and cannot be parsed. Please check the dataset and ensure it follows the format in the documentation.
# [07/29/2020 03:59:14 INFO 139835754809152] #quality_metric: host=algo-1, epoch=0, batch=174 train cross_entropy <loss>=(1.0994476548982186)
# [07/29/2020 03:59:14 INFO 139835754809152] #quality_metric: host=algo-1, epoch=0, batch=174 train smooth_l1 <loss>=(0.6444314754870079)
# [07/29/2020 03:59:14 INFO 139835754809152] Round of batches complete
# [07/29/2020 03:59:14 INFO 139835754809152] Updated the metrics
# [07/29/2020 03:59:26 INFO 139835754809152] #quality_metric: host=algo-1, epoch=0, validation mAP <score>=(0.08795914771794217)
# [07/29/2020 03:59:26 INFO 139835754809152] Updating the best model with validation-mAP=0.08795914771794217
# [07/29/2020 03:59:26 INFO 139835754809152] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/29/2020 03:59:26 INFO 139835754809152] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1595995166.657896, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 0}, "StartTime": 1595995093.976837}
#
# [07/29/2020 04:00:00 INFO 139835754809152] Epoch:    1, batches:    100, num_examples:   1600, 48.0 samples/sec, epoch time so far:  0:00:33.360705
# [07/29/2020 04:00:22 INFO 139835754809152] #quality_metric: host=algo-1, epoch=1, batch=173 train cross_entropy <loss>=(0.8536037752469429)
# [07/29/2020 04:00:22 INFO 139835754809152] #quality_metric: host=algo-1, epoch=1, batch=173 train smooth_l1 <loss>=(0.5827382901162139)
# [07/29/2020 04:00:22 INFO 139835754809152] Round of batches complete
# [07/29/2020 04:00:22 INFO 139835754809152] Updated the metrics
# [07/29/2020 04:00:32 INFO 139835754809152] #quality_metric: host=algo-1, epoch=1, validation mAP <score>=(0.35427988517407405)
# [07/29/2020 04:00:32 INFO 139835754809152] Updating the best model with validation-mAP=0.35427988517407405
# [07/29/2020 04:00:32 INFO 139835754809152] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/29/2020 04:00:32 INFO 139835754809152] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1595995232.424379, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 1}, "StartTime": 1595995166.658178}
#
# [07/29/2020 04:01:05 INFO 139835754809152] Epoch:    2, batches:    100, num_examples:   1600, 48.3 samples/sec, epoch time so far:  0:00:33.114046
# [07/29/2020 04:01:27 INFO 139835754809152] #quality_metric: host=algo-1, epoch=2, batch=173 train cross_entropy <loss>=(0.7278067257832105)
# [07/29/2020 04:01:27 INFO 139835754809152] #quality_metric: host=algo-1, epoch=2, batch=173 train smooth_l1 <loss>=(0.5282877203392115)
# [07/29/2020 04:01:27 INFO 139835754809152] Round of batches complete
# [07/29/2020 04:01:28 INFO 139835754809152] Updated the metrics
# [07/29/2020 04:01:38 INFO 139835754809152] #quality_metric: host=algo-1, epoch=2, validation mAP <score>=(0.6908882119159939)
# [07/29/2020 04:01:38 INFO 139835754809152] Updating the best model with validation-mAP=0.6908882119159939
# [07/29/2020 04:01:38 INFO 139835754809152] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/29/2020 04:01:38 INFO 139835754809152] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1595995298.579349, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 2}, "StartTime": 1595995232.424694}
#
# [07/29/2020 04:02:11 INFO 139835754809152] Epoch:    3, batches:    100, num_examples:   1600, 48.8 samples/sec, epoch time so far:  0:00:32.801095
# [07/29/2020 04:02:33 INFO 139835754809152] #quality_metric: host=algo-1, epoch=3, batch=173 train cross_entropy <loss>=(0.6469322986130108)
# [07/29/2020 04:02:33 INFO 139835754809152] #quality_metric: host=algo-1, epoch=3, batch=173 train smooth_l1 <loss>=(0.46091580307207386)
# [07/29/2020 04:02:33 INFO 139835754809152] Round of batches complete
# [07/29/2020 04:02:33 INFO 139835754809152] Updated the metrics
# [07/29/2020 04:02:44 INFO 139835754809152] #quality_metric: host=algo-1, epoch=3, validation mAP <score>=(0.7941363841836866)
# [07/29/2020 04:02:44 INFO 139835754809152] Updating the best model with validation-mAP=0.7941363841836866
# [07/29/2020 04:02:44 INFO 139835754809152] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/29/2020 04:02:44 INFO 139835754809152] #progress_metric: host=algo-1, completed 26 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1595995364.734872, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 3}, "StartTime": 1595995298.579671}
#
# [07/29/2020 04:03:17 INFO 139835754809152] Epoch:    4, batches:    100, num_examples:   1600, 49.1 samples/sec, epoch time so far:  0:00:32.610346
# [07/29/2020 04:03:40 INFO 139835754809152] #quality_metric: host=algo-1, epoch=4, batch=173 train cross_entropy <loss>=(0.6046668179930952)
# [07/29/2020 04:03:40 INFO 139835754809152] #quality_metric: host=algo-1, epoch=4, batch=173 train smooth_l1 <loss>=(0.38094861187071744)
# [07/29/2020 04:03:40 INFO 139835754809152] Round of batches complete
# [07/29/2020 04:03:40 INFO 139835754809152] Updated the metrics
# [07/29/2020 04:03:51 INFO 139835754809152] #quality_metric: host=algo-1, epoch=4, validation mAP <score>=(0.8718626830586829)
# [07/29/2020 04:03:51 INFO 139835754809152] Updating the best model with validation-mAP=0.8718626830586829
# [07/29/2020 04:03:51 INFO 139835754809152] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/29/2020 04:03:51 INFO 139835754809152] #progress_metric: host=algo-1, completed 33 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1595995431.468563, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 4}, "StartTime": 1595995364.735069}
#
# [07/29/2020 04:04:24 INFO 139835754809152] Epoch:    5, batches:    100, num_examples:   1600, 48.7 samples/sec, epoch time so far:  0:00:32.861528
# [07/29/2020 04:04:47 WARNING 139835754809152] Expected number of batches: 173, did not match the number of batches processed: 174. This may happen when some images or annotations are invalid and cannot be parsed. Please check the dataset and ensure it follows the format in the documentation.
# [07/29/2020 04:04:47 INFO 139835754809152] #quality_metric: host=algo-1, epoch=5, batch=174 train cross_entropy <loss>=(0.5688124809539492)
# [07/29/2020 04:04:47 INFO 139835754809152] #quality_metric: host=algo-1, epoch=5, batch=174 train smooth_l1 <loss>=(0.332936862066275)
# [07/29/2020 04:04:47 INFO 139835754809152] Round of batches complete
# [07/29/2020 04:04:47 INFO 139835754809152] Updated the metrics
# [07/29/2020 04:04:58 INFO 139835754809152] #quality_metric: host=algo-1, epoch=5, validation mAP <score>=(0.9262170044216644)
# [07/29/2020 04:04:58 INFO 139835754809152] Updating the best model with validation-mAP=0.9262170044216644
# [07/29/2020 04:04:59 INFO 139835754809152] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/29/2020 04:04:59 INFO 139835754809152] #progress_metric: host=algo-1, completed 40 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 6, "sum": 6.0, "min": 6}}, "EndTime": 1595995499.128525, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 5}, "StartTime": 1595995431.468886}
#
# [07/29/2020 04:05:32 INFO 139835754809152] Epoch:    6, batches:    100, num_examples:   1600, 48.1 samples/sec, epoch time so far:  0:00:33.251321
# [07/29/2020 04:05:54 INFO 139835754809152] #quality_metric: host=algo-1, epoch=6, batch=173 train cross_entropy <loss>=(0.5377634891059113)
# [07/29/2020 04:05:54 INFO 139835754809152] #quality_metric: host=algo-1, epoch=6, batch=173 train smooth_l1 <loss>=(0.299240819942947)
# [07/29/2020 04:05:54 INFO 139835754809152] Round of batches complete
# [07/29/2020 04:05:55 INFO 139835754809152] Updated the metrics
# [07/29/2020 04:06:07 INFO 139835754809152] #quality_metric: host=algo-1, epoch=6, validation mAP <score>=(0.9670690672369051)
# [07/29/2020 04:06:07 INFO 139835754809152] Updating the best model with validation-mAP=0.9670690672369051
# [07/29/2020 04:06:07 INFO 139835754809152] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/29/2020 04:06:07 INFO 139835754809152] #progress_metric: host=algo-1, completed 46 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1595995567.220125, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 6}, "StartTime": 1595995499.12881}
#
# [07/29/2020 04:06:40 INFO 139835754809152] Epoch:    7, batches:    100, num_examples:   1600, 48.7 samples/sec, epoch time so far:  0:00:32.846504
# [07/29/2020 04:07:02 INFO 139835754809152] #quality_metric: host=algo-1, epoch=7, batch=173 train cross_entropy <loss>=(0.5133873626423257)
# [07/29/2020 04:07:02 INFO 139835754809152] #quality_metric: host=algo-1, epoch=7, batch=173 train smooth_l1 <loss>=(0.2668077468296006)
# [07/29/2020 04:07:02 INFO 139835754809152] Round of batches complete
# [07/29/2020 04:07:02 INFO 139835754809152] Updated the metrics
# [07/29/2020 04:07:13 INFO 139835754809152] #quality_metric: host=algo-1, epoch=7, validation mAP <score>=(0.9708141497638512)
# [07/29/2020 04:07:13 INFO 139835754809152] Updating the best model with validation-mAP=0.9708141497638512
# [07/29/2020 04:07:14 INFO 139835754809152] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/29/2020 04:07:14 INFO 139835754809152] #progress_metric: host=algo-1, completed 53 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1595995634.019133, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 7}, "StartTime": 1595995567.221871}
#
# [07/29/2020 04:07:47 INFO 139835754809152] Epoch:    8, batches:    100, num_examples:   1600, 48.5 samples/sec, epoch time so far:  0:00:33.012982
# [07/29/2020 04:08:09 INFO 139835754809152] #quality_metric: host=algo-1, epoch=8, batch=173 train cross_entropy <loss>=(0.49445019436253645)
# [07/29/2020 04:08:09 INFO 139835754809152] #quality_metric: host=algo-1, epoch=8, batch=173 train smooth_l1 <loss>=(0.24586886388152038)
# [07/29/2020 04:08:09 INFO 139835754809152] Round of batches complete
# [07/29/2020 04:08:09 INFO 139835754809152] Updated the metrics
# [07/29/2020 04:08:20 INFO 139835754809152] #quality_metric: host=algo-1, epoch=8, validation mAP <score>=(0.9822479496755854)
# [07/29/2020 04:08:20 INFO 139835754809152] Updating the best model with validation-mAP=0.9822479496755854
# [07/29/2020 04:08:20 INFO 139835754809152] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/29/2020 04:08:20 INFO 139835754809152] #progress_metric: host=algo-1, completed 60 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 9, "sum": 9.0, "min": 9}}, "EndTime": 1595995700.782104, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 8}, "StartTime": 1595995634.01939}
#
# [07/29/2020 04:08:53 INFO 139835754809152] Epoch:    9, batches:    100, num_examples:   1600, 48.7 samples/sec, epoch time so far:  0:00:32.887044
# [07/29/2020 04:09:16 INFO 139835754809152] #quality_metric: host=algo-1, epoch=9, batch=173 train cross_entropy <loss>=(0.47948358672213154)
# [07/29/2020 04:09:16 INFO 139835754809152] #quality_metric: host=algo-1, epoch=9, batch=173 train smooth_l1 <loss>=(0.23192065290724911)
# [07/29/2020 04:09:16 INFO 139835754809152] Round of batches complete
# [07/29/2020 04:09:16 INFO 139835754809152] Updated the metrics
# [07/29/2020 04:09:27 INFO 139835754809152] #quality_metric: host=algo-1, epoch=9, validation mAP <score>=(0.9866164071709721)
# [07/29/2020 04:09:27 INFO 139835754809152] Updating the best model with validation-mAP=0.9866164071709721
# [07/29/2020 04:09:27 INFO 139835754809152] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/29/2020 04:09:27 INFO 139835754809152] #progress_metric: host=algo-1, completed 66 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1595995767.602448, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 9}, "StartTime": 1595995700.782383}
#
# [07/29/2020 04:10:00 INFO 139835754809152] Epoch:    10, batches:    100, num_examples:   1600, 48.8 samples/sec, epoch time so far:  0:00:32.790832
# [07/29/2020 04:10:23 WARNING 139835754809152] Expected number of batches: 173, did not match the number of batches processed: 174. This may happen when some images or annotations are invalid and cannot be parsed. Please check the dataset and ensure it follows the format in the documentation.
# [07/29/2020 04:10:23 INFO 139835754809152] #quality_metric: host=algo-1, epoch=10, batch=174 train cross_entropy <loss>=(0.46253001505257596)
# [07/29/2020 04:10:23 INFO 139835754809152] #quality_metric: host=algo-1, epoch=10, batch=174 train smooth_l1 <loss>=(0.21389401450624315)
# [07/29/2020 04:10:23 INFO 139835754809152] Round of batches complete
# [07/29/2020 04:10:23 INFO 139835754809152] Updated the metrics
# [07/29/2020 04:10:35 INFO 139835754809152] #quality_metric: host=algo-1, epoch=10, validation mAP <score>=(0.9894288516897762)
# [07/29/2020 04:10:35 INFO 139835754809152] Updating the best model with validation-mAP=0.9894288516897762
# [07/29/2020 04:10:35 INFO 139835754809152] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/29/2020 04:10:35 INFO 139835754809152] #progress_metric: host=algo-1, completed 73 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1595995835.194747, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 10}, "StartTime": 1595995767.602809}
#
# [07/29/2020 04:11:07 INFO 139835754809152] Epoch:    11, batches:    100, num_examples:   1600, 48.9 samples/sec, epoch time so far:  0:00:32.689497
# [07/29/2020 04:11:30 INFO 139835754809152] #quality_metric: host=algo-1, epoch=11, batch=173 train cross_entropy <loss>=(0.44627444930733773)
# [07/29/2020 04:11:30 INFO 139835754809152] #quality_metric: host=algo-1, epoch=11, batch=173 train smooth_l1 <loss>=(0.20354864405456663)
# [07/29/2020 04:11:30 INFO 139835754809152] Round of batches complete
# [07/29/2020 04:11:30 INFO 139835754809152] Updated the metrics
# [07/29/2020 04:11:41 INFO 139835754809152] #quality_metric: host=algo-1, epoch=11, validation mAP <score>=(0.9917478173858275)
# [07/29/2020 04:11:41 INFO 139835754809152] Updating the best model with validation-mAP=0.9917478173858275
# [07/29/2020 04:11:41 INFO 139835754809152] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/29/2020 04:11:41 INFO 139835754809152] #progress_metric: host=algo-1, completed 80 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 12, "sum": 12.0, "min": 12}}, "EndTime": 1595995901.906131, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 11}, "StartTime": 1595995835.195251}
#
# [07/29/2020 04:12:14 INFO 139835754809152] Epoch:    12, batches:    100, num_examples:   1600, 48.6 samples/sec, epoch time so far:  0:00:32.925841
# [07/29/2020 04:12:36 INFO 139835754809152] #quality_metric: host=algo-1, epoch=12, batch=173 train cross_entropy <loss>=(0.4399515569755667)
# [07/29/2020 04:12:36 INFO 139835754809152] #quality_metric: host=algo-1, epoch=12, batch=173 train smooth_l1 <loss>=(0.1904144324247352)
# [07/29/2020 04:12:36 INFO 139835754809152] Round of batches complete
# [07/29/2020 04:12:37 INFO 139835754809152] Updated the metrics
# [07/29/2020 04:12:48 INFO 139835754809152] #quality_metric: host=algo-1, epoch=12, validation mAP <score>=(0.9914648018709677)
# [07/29/2020 04:12:48 INFO 139835754809152] #progress_metric: host=algo-1, completed 86 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 13, "sum": 13.0, "min": 13}}, "EndTime": 1595995968.420007, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 12}, "StartTime": 1595995901.906378}
#
# [07/29/2020 04:13:21 INFO 139835754809152] Epoch:    13, batches:    100, num_examples:   1600, 49.0 samples/sec, epoch time so far:  0:00:32.654832
# [07/29/2020 04:13:42 INFO 139835754809152] #quality_metric: host=algo-1, epoch=13, batch=173 train cross_entropy <loss>=(0.4256145379216937)
# [07/29/2020 04:13:42 INFO 139835754809152] #quality_metric: host=algo-1, epoch=13, batch=173 train smooth_l1 <loss>=(0.18140061729893192)
# [07/29/2020 04:13:42 INFO 139835754809152] Round of batches complete
# [07/29/2020 04:13:43 INFO 139835754809152] Updated the metrics
# [07/29/2020 04:13:54 INFO 139835754809152] #quality_metric: host=algo-1, epoch=13, validation mAP <score>=(0.9887674617804499)
# [07/29/2020 04:13:54 INFO 139835754809152] #progress_metric: host=algo-1, completed 93 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 14, "sum": 14.0, "min": 14}}, "EndTime": 1595996034.43539, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 13}, "StartTime": 1595995968.420252}
#
# [07/29/2020 04:14:26 INFO 139835754809152] Epoch:    14, batches:    100, num_examples:   1600, 49.5 samples/sec, epoch time so far:  0:00:32.297539
#
# 2020-07-29 04:15:02 Uploading - Uploading generated training model[07/29/2020 04:14:48 INFO 139835754809152] #quality_metric: host=algo-1, epoch=14, batch=173 train cross_entropy <loss>=(0.41785223693374896)
# [07/29/2020 04:14:48 INFO 139835754809152] #quality_metric: host=algo-1, epoch=14, batch=173 train smooth_l1 <loss>=(0.17933576955686154)
# [07/29/2020 04:14:48 INFO 139835754809152] Round of batches complete
# [07/29/2020 04:14:48 INFO 139835754809152] Updated the metrics
# [07/29/2020 04:14:59 INFO 139835754809152] #quality_metric: host=algo-1, epoch=14, validation mAP <score>=(0.9938997379505341)
# [07/29/2020 04:14:59 INFO 139835754809152] Updating the best model with validation-mAP=0.9938997379505341
# [07/29/2020 04:14:59 INFO 139835754809152] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/29/2020 04:14:59 INFO 139835754809152] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1595996099.979098, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 14}, "StartTime": 1595996034.435616}
#
# [07/29/2020 04:14:59 WARNING 139835754809152] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [07/29/2020 04:15:00 INFO 139835754809152] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [07/29/2020 04:15:00 INFO 139835754809152] Test data is not provided.
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}, "totaltime": {"count": 1, "max": 1033871.1280822754, "sum": 1033871.1280822754, "min": 1033871.1280822754}, "setuptime": {"count": 1, "max": 11.35396957397461, "sum": 11.35396957397461, "min": 11.35396957397461}}, "EndTime": 1595996101.249514, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1595995067.502201}
#
#
# 2020-07-29 04:15:19 Completed - Training job completed
# Training seconds: 1152
# Billable seconds: 1152

# %% [markdown]
# # Deploy Model

# %%
deployed_model = model.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
print('\nModel deployed!')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# -----------------!
# Model deployed!

# %% [markdown]
# # Predictions

# %%
image_dir = 'validation'
images = [x for x in os.listdir(image_dir) if x[-3:] == 'jpg']
print(len(images))
# Out:
# 915

# %%
deployed_model.content_type = 'image/jpeg'

# %%
index = 129

image_path = os.path.join(image_dir, images[index])
#image_path = 'dog_cat.jfif'

with open(image_path, 'rb') as f:
    b = bytearray(f.read())

results = deployed_model.predict(b)
results = json.loads(results)

preds = results['prediction']

# %%
preds
# Out:
# [[1.0,
#   0.9163071513175964,
#   0.35251542925834656,
#   0.04010671377182007,
#   0.876798152923584,
#   0.9754077792167664],
#  [1.0,
#   0.112303726375103,
#   0.4333467483520508,
#   0.4713667631149292,
#   0.8726701736450195,
#   0.9964091777801514],
#  [1.0,
#   0.0487220399081707,
#   0.3871377110481262,
#   0.5741996169090271,
#   0.7165586352348328,
#   0.9438217282295227],
#  [1.0,
#   0.039944082498550415,
#   0.7437886595726013,
#   0.09445573389530182,
#   0.8970972895622253,
#   0.2691836357116699],
#  [1.0,
#   0.038403842598199844,
#   0.23952743411064148,
#   0.3369840979576111,
#   0.9603055715560913,
#   0.8304921984672546],
#  [1.0,
#   0.03260699659585953,
#   0.4065539836883545,
#   0.0,
#   0.7579891681671143,
#   0.5577266812324524],
#  [1.0,
#   0.031117476522922516,
#   0.048595815896987915,
#   0.38686323165893555,
#   0.7507559061050415,
#   0.9915266036987305],
#  [1.0, 0.03009078837931156, 0.0, 0.42034605145454407, 0.2879827618598938, 1.0],
#  [1.0,
#   0.024882612749934196,
#   0.5903410315513611,
#   0.5799582600593567,
#   0.9281018376350403,
#   0.9363195300102234],
#  [1.0,
#   0.024801598861813545,
#   0.0,
#   0.8783748149871826,
#   0.12406038492918015,
#   1.0],
#  [1.0,
#   0.024249348789453506,
#   0.19546934962272644,
#   0.11461636424064636,
#   0.9345279932022095,
#   0.6203268766403198],
#  [1.0,
#   0.02319861389696598,
#   0.0,
#   0.5087018013000488,
#   0.07305125892162323,
#   0.5799747705459595],
#  [1.0,
#   0.022220171988010406,
#   0.8182585835456848,
#   0.14488962292671204,
#   0.8961780667304993,
#   0.010825267992913723,
#   0.32719600200653076,
#   0.0,
#   0.393798291683197,
#   0.08281885087490082],
#  [1.0,
#   0.010822614654898643,
#   0.4682760536670685,
#   0.13744790852069855,
#   0.6336626410484314,
#   0.3558022975921631],
#  [0.0,
#   0.01075633242726326,
#   0.007412172853946686,
#   0.40316760540008545,
#   0.14779818058013916,
#   0.5582919716835022],
#  [1.0,
#   0.010748098604381084,
#   0.7038020491600037,
#   0.0,
#   0.8567582964897156,
#   0.14304986596107483],
#  [1.0,
#   0.010728534311056137,
#   0.14777687191963196,
#   0.0,
#   0.2844887375831604,
#   0.160690039396286],
#  [0.0,
#   0.010658025741577148,
#   0.24876722693443298,
#   0.0,
#   0.4061611592769623,
#   0.09258191287517548],
#  [1.0,
#   0.010643488727509975,
#   0.8540591597557068,
#   0.2079225778579712,
#   0.9280150532722473,
#   0.3258674144744873],
#  [0.0,
#   0.010611701756715775,
#   0.0,
#   0.6512717604637146,
#   0.04850701615214348,
#   0.7661243081092834],
#  [0.0, 0.010544264689087868, 0.9134594202041626, 0.8946483135223389, 1.0, 1.0],
#  [1.0,
#   0.010492011904716492,
#   0.17111623287200928,
#   0.3232243061065674,
#   0.29536712169647217,
#   0.39570122957229614],
#  [1.0,
#   0.010378673672676086,
#   0.9530861973762512,
#   0.23612916469573975,
#   1.0,
#   0.36270999908447266],
#  [1.0,
#   0.010245958343148232,
#   0.27358323335647583,
#   0.0,
#   0.4102016091346741,
#   0.16543307900428772],
#  [1.0,
#   0.010185540653765202,
#   0.6407129168510437,
#   0.0,
#   0.7944418787956238,
#   0.14583323895931244],
#  [1.0,
#   0.01014767400920391,
#   0.8129626512527466,
#   0.09468968212604523,
#   0.8958019018173218,
#   0.21126390993595123],
#  [1.0,
#   0.010111561976373196,
#   0.0,
#   0.41484659910202026,
#   0.06860934942960739,
#   0.4903606176376343],
#  [1.0,
#   0.010072354227304459,
#   0.10124308615922928,
#   0.6808733940124512,
#   0.25287190079689026,
#   0.8587056398391724],
#  [1.0,
#   0.010069007985293865,
#   0.7554388642311096,
#   0.45350533723831177,
#   0.835847795009613,
#   0.5833384394645691],
#  [1.0,
#   0.01004268229007721,
#   0.1582869291305542,
#   0.0,
#   0.40880030393600464,
#   0.09723182022571564],
#  [1.0,
#   0.010011803358793259,
#   0.2564012408256531,
#   0.8700331449508667,
#   0.44023579359054565,
#   1.0]]

# %%
img = Image.open(image_path)
draw = ImageDraw.Draw(img)
font = ImageFont.truetype('/usr/share/fonts/dejavu/DejaVuSerif-Bold.ttf', 30)
w, h =img.size

for pred in preds:
    class_id, score, xmin, ymin, xmax, ymax = pred
    
    if score > 0.7:
        box = [w*xmin, h*ymin, w*xmax, h*ymax]

        draw.rectangle(box, outline='yellow', width=4)
        draw.text((box[0], box[1]), classes[int(class_id)], font=font, fill='#000000')
    else:
        break

plt.xticks([])
plt.yticks([])
plt.imshow(img)
plt.show()

# %% [markdown]
# Delete Endpoint!

# %%
sagemaker.Session().delete_endpoint(deployed_model.endpoint)
